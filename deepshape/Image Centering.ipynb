# %%
# %load_ext autoreload
# %autoreload 2

# %%
import idx2numpy
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from deepshape.surfaces import *

# %%
file = "../data/t10k-images.idx3-ubyte"
data = torch.tensor( idx2numpy.convert_from_file(file) )
labelfile = "../data/t10k-labels.idx1-ubyte"
labels = torch.tensor( idx2numpy.convert_from_file(labelfile))

# %%
## k=64
digit = 0
digits = data[labels==digit]

img_idx = 9
im = digits[img_idx:img_idx+3].detach() / 255.

plt.imshow(im.permute(1, 2, 0))
plt.colorbar()
plt.show()
find_center(im)
# Out:
# (tensor(13.9687), tensor(13.9687))

# %%
x = torch.arange(28)
x.shape

y = torch.arange(28).view(-1, 1)

# %%
plt.imshow(x * im)

# %%
plt.imshow(y * im)
