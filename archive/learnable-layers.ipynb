# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from deepshape.curves import BumpReluLayer

# %%
x = torch.linspace(0, 1, 1024).unsqueeze(-1)

layer = BumpReluLayer(100)
layer.project()

z, y = layer(x)

plt.plot(x.numpy().flatten(), z.detach().numpy().flatten())
plt.figure()
plt.plot(x.numpy().flatten(), y.detach().numpy().flatten())
plt.show()
